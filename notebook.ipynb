# %% [markdown]
# <a href="https://colab.research.google.com/github/sebastianrjay/A-BTestExample/blob/master/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/a1-sebastianrjay/
# Out:
# evaluate_famous_models.py     part2_roofline_plot.png		part4_cpu_tflops.png
# forward_flops_resnet18.png    part3_cpu_correlation_matrix.png	part4_gpu_bytes.png
# forward_latency_resnet18.png  part3_cpu_latency_flops.png	part4_gpu_flops_per_byte.png
# forward_memory_resnet18.png   part3_cpu_latency_params.png	part4_gpu_flops.png
# images			      part3_cpu_throughput.png		part4.py
# model_flops_memory_plot.png   part3_gpu_correlation_matrix.png	part5_FLOPs_ratio.png
# model_roofline_plot.png       part3_gpu_latency_flops.png	part5_Latency_ratio.png
# notebook.ipynb		      part3_gpu_latency_params.png	part5.py
# part1.py		      part3_gpu_throughput.png		__pycache__
# part1_roofline_plot.png       part3.py				README.md
# part2_model_analysis.png      part4_cpu_flops_per_byte.png
# part2.py		      part4_cpu_megabytes.png

# %%
# %cd /content/drive/MyDrive/a1-sebastianrjay/
# Out:
# /content/drive/MyDrive/a1-sebastianrjay

# %%
# !pip install ptflops thop
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 68.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 50.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
from PIL import Image
from IPython.display import display

image = Image.open('part2_model_analysis.png')
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x600>

# %%
image = Image.open('part2_roofline_plot.png')
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600>

# %%
# !python part3.py
# Out:
# /content/drive/MyDrive/a1-sebastianrjay/part3.py:64: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab10', len(MODEL_NAMES))  # Using tab10 colormap for distinct colors
# Benchmarking model resnet18 on gpu with batch size 1
# Benchmarking model resnet18 on gpu with batch size 64
# Benchmarking model resnet18 on gpu with batch size 256
# Benchmarking model resnet50 on gpu with batch size 1
# Benchmarking model resnet50 on gpu with batch size 64
# Benchmarking model resnet50 on gpu with batch size 256
# Benchmarking model vgg16 on gpu with batch size 1
# Benchmarking model vgg16 on gpu with batch size 64
# Benchmarking model vgg16 on gpu with batch size 256
# Benchmarking model inception_v3 on gpu with batch size 1
# ...

# %%
from PIL import Image
from IPython.display import display

image = Image.open('part3_correlation_matrix_gpu.png')
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600>

# %%
# !mv part3_correlation_matrix_gpu.png part3_gpu_correlation_matrix.png

# %%
from PIL import Image
from IPython.display import display
image = Image.open('part3_gpu_latency_flops.png')
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x600>

# %%
from PIL import Image
from IPython.display import display
image = Image.open('part3_gpu_latency_params.png')
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x600>

# %%
from PIL import Image
from IPython.display import display
image = Image.open('part3_gpu_throughput.png')
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x600>

# %%
# !python part3.py
# Out:
# /content/drive/MyDrive/a1-sebastianrjay/part3.py:64: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab10', len(MODEL_NAMES))  # Using tab10 colormap for distinct colors
# Benchmarking model resnet18 on gpu with batch size 1
# Benchmarking model resnet18 on gpu with batch size 64
# Benchmarking model resnet18 on gpu with batch size 256
# Benchmarking model resnet50 on gpu with batch size 1
# Benchmarking model resnet50 on gpu with batch size 64
# Benchmarking model resnet50 on gpu with batch size 256
# Benchmarking model vgg16 on gpu with batch size 1
# Benchmarking model vgg16 on gpu with batch size 64
# Benchmarking model vgg16 on gpu with batch size 256
# Benchmarking model inception_v3 on gpu with batch size 1
# ...

# %%
# !python part3.py
# Out:
# /content/drive/MyDrive/a1-sebastianrjay/part3.py:64: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab10', len(MODEL_NAMES))  # Using tab10 colormap for distinct colors
# Benchmarking model resnet18 on gpu with batch size 1
# Benchmarking model resnet18 on gpu with batch size 64
# Benchmarking model resnet18 on gpu with batch size 256
# Benchmarking model resnet50 on gpu with batch size 1
# Benchmarking model resnet50 on gpu with batch size 64
# Benchmarking model resnet50 on gpu with batch size 256
# Benchmarking model vgg16 on gpu with batch size 1
# Benchmarking model vgg16 on gpu with batch size 64
# Benchmarking model vgg16 on gpu with batch size 256
# Benchmarking model inception_v3 on gpu with batch size 1
# ...

# %%
# !python part3.py
# Out:
# /content/drive/MyDrive/a1-sebastianrjay/part3.py:64: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab10', len(MODEL_NAMES))  # Using tab10 colormap for distinct colors
# Benchmarking model resnet18 on gpu with batch size 1
# Benchmarking model resnet18 on gpu with batch size 64
# Benchmarking model resnet18 on gpu with batch size 256
# Benchmarking model resnet50 on gpu with batch size 1
# Benchmarking model resnet50 on gpu with batch size 64
# Benchmarking model resnet50 on gpu with batch size 256
# Benchmarking model vgg16 on gpu with batch size 1
# Benchmarking model vgg16 on gpu with batch size 64
# Benchmarking model vgg16 on gpu with batch size 256
# Benchmarking model inception_v3 on gpu with batch size 1
# ...

# %%
from PIL import Image
from IPython.display import display
image = Image.open('part3_gpu_latency_params.png')
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x600>

# %%
from PIL import Image
from IPython.display import display
image = Image.open('part3_gpu_latency_flops.png')
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x600>

# %%
from PIL import Image
from IPython.display import display
image = Image.open('part3_gpu_throughput.png')
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x600>

# %%
from PIL import Image
from IPython.display import display
image = Image.open('part3_gpu_correlation_matrix.png')
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600>

# %%
# !python part3.py
# Out:
# /content/drive/MyDrive/a1-sebastianrjay/part3.py:63: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab10', len(MODEL_NAMES))  # Using tab10 colormap for distinct colors
# Benchmarking model resnet18 on gpu with batch size 1
# Benchmarking model resnet18 on gpu with batch size 64
# Benchmarking model resnet18 on gpu with batch size 256
# Benchmarking model resnet50 on gpu with batch size 1
# Benchmarking model resnet50 on gpu with batch size 64
# Benchmarking model resnet50 on gpu with batch size 256
# Benchmarking model vgg16 on gpu with batch size 1
# Benchmarking model vgg16 on gpu with batch size 64
# Benchmarking model vgg16 on gpu with batch size 256
# Benchmarking model inception_v3 on gpu with batch size 1
# ...

# %%
from PIL import Image
from IPython.display import display
image = Image.open('part3_gpu_correlation_matrix.png')
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600>

# %%
# !python part4.py
# Out:
# Analyzing model resnet18 on device: gpu
# Analyzing model resnet50 on device: gpu
# Analyzing model vgg16 on device: gpu
# Analyzing model inception_v3 on device: gpu
# /usr/local/lib/python3.11/dist-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# Analyzing model mobilenet_v2 on device: gpu
# Analyzing model densenet121 on device: gpu
# Analyzing model efficientnet_b0 on device: gpu
# Analyzing model alexnet on device: gpu
# Analyzing model squeezenet1_0 on device: gpu
# Analyzing model googlenet on device: gpu
# ...

# %%
from PIL import Image
from IPython.display import display
image = Image.open('part4_gpu_bytes.png')
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x600>

# %%
# !python part3.py
# Out:
# /content/drive/MyDrive/a1-sebastianrjay/part3.py:63: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab10', len(MODEL_NAMES))  # Using tab10 colormap for distinct colors
# Benchmarking model resnet18 on cpu with batch size 1
# Benchmarking model resnet18 on cpu with batch size 64
# Benchmarking model resnet18 on cpu with batch size 256
# Benchmarking model resnet50 on cpu with batch size 1
# Benchmarking model resnet50 on cpu with batch size 64
# Benchmarking model resnet50 on cpu with batch size 256
# Benchmarking model vgg16 on cpu with batch size 1
# Benchmarking model vgg16 on cpu with batch size 64
# Benchmarking model vgg16 on cpu with batch size 256
# Benchmarking model inception_v3 on cpu with batch size 1
# ...
